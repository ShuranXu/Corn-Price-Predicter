# %% [markdown]
# # Daily Corn Price Forecasting using Linear Regression

# %%
# Project 3      
#importing libraries 
import pandas as pd
import numpy as np
import seaborn as sns 
import datetime 
import os
import matplotlib.pyplot as plt
from pathlib import Path
# %matplotlib inline
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 1. Data Import and Cleanup

# %%
# Read in corn actual price and sort by date
corn_act_prices = pd.read_csv(Path("../Resources/combined_portfolios_df.csv"), index_col="Date", infer_datetime_format=True, parse_dates=True).sort_index()
# Dropping Natural Gas and Corn Future
corn_act_prices = corn_act_prices.drop(columns=["Natural_Gas_future", "Corn_future"])
corn_act_prices.head(2), corn_act_prices.tail(2)
# Out:
# (            Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
#  Date
#  2005-03-28      2.1275  84.620003           1.230  4.336889  13.597000
#  2005-03-29      2.1300  84.320000           1.225  2.400000  17.326667
#
#               avg_min
#  Date
#  2005-03-28  0.724167
#  2005-03-29  2.610167  ,
#              Corn_Price  USD_Index  Ethanol_future  avg_prcp   avg_max  \
#  Date
#  2020-11-25      4.2300  91.989998            1.37  9.818667  8.318667
#  2020-11-30      4.2475  91.870003            1.40  1.456000  8.385714
#
#               avg_min
#  Date
#  2020-11-25 -0.938833
#  2020-11-30 -4.750714  )

# %%
# Drop nulls from Corn DataFrame
corn_act_prices.dropna(inplace=True)

# %% [markdown]
# ## 2. Understanding the Dataset

# %%
corn_act_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3887 entries, 2005-03-28 to 2020-11-30
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Corn_Price      3887 non-null   float64
#  1   USD_Index       3887 non-null   float64
#  2   Ethanol_future  3887 non-null   float64
#  3   avg_prcp        3887 non-null   float64
#  4   avg_max         3887 non-null   float64
#  5   avg_min         3887 non-null   float64
# dtypes: float64(6)
# memory usage: 212.6 KB

# %%
# Looking at the datasets with respect to each variable in pairs
sns.pairplot(corn_act_prices)

# %%
# Checking datasets size
corn_act_prices.shape
# Out:
# (3887, 6)

# %%
#Display Sample Data
corn_act_prices.tail()
# Out:
#             Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
# Date
# 2020-11-20      4.2325  92.400002            1.39  0.000000  18.355167
# 2020-11-23      4.2650  92.510002            1.41  4.220000   7.662000
# 2020-11-24      4.2710  92.230003            1.41  3.550333   6.440000
# 2020-11-25      4.2300  91.989998            1.37  9.818667   8.318667
# 2020-11-30      4.2475  91.870003            1.40  1.456000   8.385714
#
#              avg_min
# Date
# 2020-11-20  3.967333
# 2020-11-23 -2.253167
# 2020-11-24 -2.269556
# 2020-11-25 -0.938833
# 2020-11-30 -4.750714

# %% [markdown]
# ## 3. Preparing Data for future forecasting

# %%
# Creating a lag of 90 days to predict for future three months
corn_act_prices['Corn_Price_3Mo_Forward']=corn_act_prices['Corn_Price'].shift(-90)
corn_act_prices.head(10)
# Out:
#             Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
# Date
# 2005-03-28      2.1275  84.620003           1.230  4.336889  13.597000
# 2005-03-29      2.1300  84.320000           1.225  2.400000  17.326667
# 2005-03-30      2.1250  84.290001           1.215  1.930222  19.458595
# 2005-03-31      2.1300  84.059998           1.230  3.886190  19.090190
# 2005-04-01      2.1275  84.430000           1.215  2.267937  15.113492
# 2005-04-04      2.0975  84.779999           1.200  0.051429  20.211825
# 2005-04-05      2.0550  84.660004           1.205  0.362857  22.704048
# 2005-04-06      2.0725  84.680000           1.200  0.796667  22.383056
# 2005-04-07      2.0550  84.870003           1.160  2.912413  21.270635
# 2005-04-08      2.0400  84.470001           1.150  0.492698  18.531468
#
#              avg_min  Corn_Price_3Mo_Forward
# Date
# 2005-03-28  0.724167                  2.2700
# 2005-03-29  2.610167                  2.2450
# 2005-03-30  4.586810                  2.2050
# 2005-03-31  4.220071                  2.2200
# 2005-04-01  1.574048                  2.1875
# 2005-04-04  3.224167                  2.2300
# 2005-04-05  6.176746                  2.2500
# 2005-04-06  8.444444                  2.1775
# 2005-04-07  6.804881                  2.1050
# 2005-04-08  3.848571                  2.0950

# %%
#Preparing the data for future forecast of 90 days
forecast_90 = corn_act_prices[-90:]
forecast_90.head(2)
# Out:
#             Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
# Date
# 2020-07-23      3.2800  94.690002            1.17  2.141667  28.747833
# 2020-07-24      3.2625  94.440002            1.15  1.645833  29.363556
#
#               avg_min  Corn_Price_3Mo_Forward
# Date
# 2020-07-23  18.642000                     NaN
# 2020-07-24  18.636889                     NaN

# %%
# Dropping NUll values
corn_act_prices=corn_act_prices.dropna()
corn_act_prices.head()
# Out:
#             Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
# Date
# 2005-03-28      2.1275  84.620003           1.230  4.336889  13.597000
# 2005-03-29      2.1300  84.320000           1.225  2.400000  17.326667
# 2005-03-30      2.1250  84.290001           1.215  1.930222  19.458595
# 2005-03-31      2.1300  84.059998           1.230  3.886190  19.090190
# 2005-04-01      2.1275  84.430000           1.215  2.267937  15.113492
#
#              avg_min  Corn_Price_3Mo_Forward
# Date
# 2005-03-28  0.724167                  2.2700
# 2005-03-29  2.610167                  2.2450
# 2005-03-30  4.586810                  2.2050
# 2005-03-31  4.220071                  2.2200
# 2005-04-01  1.574048                  2.1875

# %%
#Display sample
corn_act_prices.tail()
# Out:
#             Corn_Price  USD_Index  Ethanol_future   avg_prcp    avg_max  \
# Date
# 2020-07-16      3.3025  96.349998           1.205  10.438889  28.212778
# 2020-07-17      3.3300  95.940002           1.170   0.156667  29.672000
# 2020-07-20      3.2825  95.830002           1.107   8.823016  29.965333
# 2020-07-21      3.2275  95.120003           1.107   3.585000  28.184111
# 2020-07-22      3.2750  94.970001           1.190  10.772063  28.836667
#
#               avg_min  Corn_Price_3Mo_Forward
# Date
# 2020-07-16  17.307556                  4.2325
# 2020-07-17  17.960556                  4.2650
# 2020-07-20  18.710000                  4.2710
# 2020-07-21  18.309000                  4.2300
# 2020-07-22  18.476000                  4.2475

# %%
# Data checks
corn_act_prices.shape
# Out:
# (3797, 7)

# %% [markdown]
# ## 4. Training and Validation Datasplit

# %%
# Train Test Split of 80% 20%
train = corn_act_prices.loc['2005-03-28':'2017-05-31']
test = corn_act_prices.loc['2017-06-1':]
train.shape, train.tail(2), test.shape, test.head(2)
# Out:
# ((3016, 7),
#              Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
#  Date
#  2017-05-30        3.67  97.279999           1.515      0.55  24.684667
#  2017-05-31        3.72  96.919998           1.524      0.32  24.146000
#
#                avg_min  Corn_Price_3Mo_Forward
#  Date
#  2017-05-30  10.466000                   3.500
#  2017-05-31   9.491556                   3.495  ,
#  (781, 7),
#              Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
#  Date
#  2017-06-01      3.7050  97.199997           1.529      0.44  24.675556
#  2017-06-02      3.7275  96.720001           1.554      0.00  27.198000
#
#                avg_min  Corn_Price_3Mo_Forward
#  Date
#  2017-06-01  10.390667                  3.4925
#  2017-06-02  11.127778                  3.4600  )

# %% [markdown]
# ## 5. Prepare the Features (X) and the Target (y)

# %%
# Create dataframes for X_train and X_test, series for y_train and y_test
# X_train (training set using just the independent variables), X_test (test set of of just the independent variables)
# Y_train (training set using just the "y" variable, i.e., "Futures Return"), Y_test (test set of just the "y" variable):
X_train = train.drop(columns=["Corn_Price_3Mo_Forward"])
X_test = test.drop(columns=["Corn_Price_3Mo_Forward"])

y_train = train["Corn_Price_3Mo_Forward"]
y_test = test["Corn_Price_3Mo_Forward"]

# %%
# Display Samples
X_train.head(3)
# Out:
#             Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
# Date
# 2005-03-28      2.1275  84.620003           1.230  4.336889  13.597000
# 2005-03-29      2.1300  84.320000           1.225  2.400000  17.326667
# 2005-03-30      2.1250  84.290001           1.215  1.930222  19.458595
#
#              avg_min
# Date
# 2005-03-28  0.724167
# 2005-03-29  2.610167
# 2005-03-30  4.586810

# %%
# Display some samples
y_train[:3], y_test[:3]
# Out:
# (Date
#  2005-03-28    2.270
#  2005-03-29    2.245
#  2005-03-30    2.205
#  Name: Corn_Price_3Mo_Forward, dtype: float64,
#  Date
#  2017-06-01    3.4925
#  2017-06-02    3.4600
#  2017-06-05    3.4900
#  Name: Corn_Price_3Mo_Forward, dtype: float64)

# %%
# Display Samples
X_test.head(3)
# Out:
#             Corn_Price  USD_Index  Ethanol_future  avg_prcp    avg_max  \
# Date
# 2017-06-01      3.7050  97.199997           1.529  0.440000  24.675556
# 2017-06-02      3.7275  96.720001           1.554  0.000000  27.198000
# 2017-06-05      3.7300  96.800003           1.554  1.466667  30.623556
#
#               avg_min
# Date
# 2017-06-01  10.390667
# 2017-06-02  11.127778
# 2017-06-05  15.971778

# %%
# Data Checks
y_train.dtype, y_test.dtype
# Out:
# (dtype('float64'), dtype('float64'))

# %% [markdown]
# ## 6. Linear Regression Model Development

# %%
#Fit a SKLearn linear regression using  just the training set (X_train, Y_train):
model = LinearRegression()
model.fit(X_train, y_train)
print(model.coef_)
print(model.intercept_)
# Out:
# [ 0.73625929 -0.03217541 -0.31504141 -0.00878399  0.00983505 -0.01646369]
# 4.4999396987778395

# %% [markdown]
# ## 7. Future Forecast

# %%
#Looking at the model parameters in dataframe
pd.DataFrame(model.coef_, X_train.columns, columns = ['Coeff'])
# Out:
#                    Coeff
# Corn_Price      0.736259
# USD_Index      -0.032175
# Ethanol_future -0.315041
# avg_prcp       -0.008784
# avg_max         0.009835
# avg_min        -0.016464

# %%
# Next 90 days prediction
forecast_90 = forecast_90.drop(columns=["Corn_Price_3Mo_Forward"])
predictions_90 = model.predict(forecast_90)
predictions_90
# Out:
# array([3.45659014, 3.46854548, 3.45982817, 3.42678714, 3.44636556,
#        3.40638743, 3.40768531, 3.43561218, 3.39671559, 3.47335129,
#        3.47381301, 3.43536293, 3.39208011, 3.35673163, 3.43900213,
#        3.50992511, 3.47699925, 3.57537566, 3.55146855, 3.53856468,
#        3.55069959, 3.55795564, 3.54628111, 3.61521909, 3.63170557,
#        3.66547487, 3.69466972, 3.76954964, 3.75660925, 3.68731469,
#        3.71711714, 3.80558452, 3.59668057, 3.66197864, 3.75258033,
#        3.75003054, 3.87661432, 3.86125042, 3.90681716, 3.93529299,
#        3.95174074, 3.89862194, 3.88732847, 3.85438584, 3.80581276,
#        3.80326194, 3.75652605, 3.78855688, 3.8973368 , 3.95318388,
#        3.94662208, 3.95812882, 4.01680092, 4.03389198, 4.04208889,
#        4.08955627, 3.99656302, 4.03381565, 4.06840725, 4.15738248,
#        4.12316492, 4.01037534, 4.04484848, 4.07428178, 4.03229517,
#        4.1807366 , 4.15128663, 4.12852031, 4.05133765, 3.96757225,
#        3.99198926, 4.08836754, 4.15528775, 4.19806701, 4.2313801 ,
#        4.23320109, 4.15550537, 4.22077883, 4.22828786, 4.19610793,
#        4.23644459, 4.26057561, 4.30871833, 4.37074968, 4.29889835,
#        4.32044885, 4.29471325, 4.30227361, 4.23391813, 4.37808693])

# %%
daily_forecast =  pd.DataFrame(predictions_90, columns = ['Corn Price Forecast'])
daily_forecast.to_csv("../Resources/daily_forecast.csv")

# %% [markdown]
# ## 8. Make predictions using the Testing Data
# Note: We want to evaluate the model using data that it has never seen before, in this case: X_test.

# %%
# And make a prediction of "y" values for just the test dataset
predictions = model.predict(X_test)
predictions
# Out:
# array([3.68638411, 3.72705573, 3.6673795 , 3.73569277, 3.76676711,
#        3.79733664, 3.79524128, 3.65301486, 3.64040187, 3.63844181,
#        3.61332473, 3.71458048, 3.63231378, 3.63327184, 3.63393285,
#        3.5577928 , 3.42560333, 3.57192494, 3.6283827 , 3.64252942,
#        3.62306476, 3.63620542, 3.81219935, 3.78030332, 3.78412124,
#        3.83544535, 3.74678016, 3.68701558, 3.58134724, 3.69047447,
#        3.7335174 , 3.73807719, 3.76141247, 3.82305038, 3.73277419,
#        3.75815156, 3.72738599, 3.7359434 , 3.66691113, 3.71236402,
#        3.77899013, 3.70636791, 3.70044817, 3.69717698, 3.70639247,
#        3.71186356, 3.74240837, 3.77028977, 3.67939505, 3.67620789,
#        3.66080722, 3.55235611, 3.51913834, 3.56048293, 3.56947933,
#        3.56532432, 3.46231816, 3.57735361, 3.58563376, 3.57220675,
#        3.56120338, 3.54386635, 3.56176117, 3.66645137, 3.65715382,
#        3.71373374, 3.78782495, 3.77195967, 3.79734685, 3.76646695,
#        3.70819253, 3.65510015, 3.6737668 , 3.70537601, 3.65069707,
#        3.60025821, 3.57577878, 3.60835272, 3.6760726 , 3.64995006,
#        3.59747953, 3.66237561, 3.69557942, 3.72904064, 3.6765843 ,
#        3.61791091, 3.61354906, 3.56661049, 3.52481257, 3.62159731,
#        3.62643339, 3.51854361, 3.64147556, 3.65993303, 3.73992472,
#        3.75130257, 3.73448332, 3.75554011, 3.71122173, 3.63609792,
#        3.64022051, 3.69735925, 3.72433171, 3.70785861, 3.68021571,
#        3.66434951, 3.62755833, 3.64157667, 3.59959278, 3.55331345,
#        3.60207679, 3.68301546, 3.67652679, 3.69346568, 3.59415372,
#        3.15368432, 3.19946559, 3.28968307, 3.25090405, 3.24522596,
#        3.27023908, 3.29587236, 3.345243  , 3.34547469, 3.42573566,
#        3.41941599, 3.40153634, 3.36863641, 3.41860963, 3.47860586,
#        3.39202578, 3.34253435, 3.45676297, 3.47808226, 3.48203947,
#        3.46218923, 3.45058106, 3.44059103, 3.40470493, 3.32200951,
#        3.30117402, 3.37767053, 3.36670797, 3.33857645, 3.35468486,
#        3.4325391 , 3.53359353, 3.45335028, 3.51717254, 3.47995844,
#        3.48946297, 3.46393871, 3.40205296, 3.39429564, 3.42018884,
#        3.38851563, 3.35254334, 3.49092837, 3.3937642 , 3.41120864,
#        3.36539627])

# %%
# Assemble actual y data (Y_test) with predicted y data (from just above) into two columns in a dataframe:
Results = y_test.to_frame()
Results["Predicted Return"] = predictions
Results.head(3)
# Out:
#             Corn_Price_3Mo_Forward  Predicted Return
# Date
# 2017-06-01                  3.4925          3.686384
# 2017-06-02                  3.4600          3.727056
# 2017-06-05                  3.4900          3.667379

# %%
# Display top 3 rows
Results.head(3), Results.tail(3)
# Out:
# (            Corn_Price_3Mo_Forward  Predicted Return
#  Date
#  2017-06-01                  3.4925          3.686384
#  2017-06-02                  3.4600          3.727056
#  2017-06-05                  3.4900          3.667379,
#              Corn_Price_3Mo_Forward  Predicted Return
#  Date
#  2020-07-20                  4.2710          3.393764
#  2020-07-21                  4.2300          3.411209
#  2020-07-22                  4.2475          3.365396)

# %%
# Plot the first 20 predictions against the true values to see how it performed
# The trends lines should be similar
Results[:20].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000202D06A9548>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000202D06D9488>],
#       dtype=object)

# %% [markdown]
# ## 9. Out-of-Sample Performance
#
# Evaluate the model using "out-of-sample" data (X_test and y_test)

# %%
from sklearn.metrics import mean_squared_error

# Calculate the mean_squared_error (MSE) on actual versus predicted test "y" 
# A "good" MSE score will be close to zero while a "good".
mse = mean_squared_error(Results["Corn_Price_3Mo_Forward"],Results["Predicted Return"])
# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Out-of-Sample Root Mean Squared Error (RMSE): {rmse}")
print(f"Standard Deviation of Futures Return: {np.std(Results.Corn_Price_3Mo_Forward)}")
# Out:
# Mean Squared Error (MSE): 0.12822577101185792
# Out-of-Sample Root Mean Squared Error (RMSE): 0.35808626197029386
# Standard Deviation of Futures Return: 0.2778982257405088

# %% [markdown]
# ## 10. In-Sample Performance
#
# Evaluate the model using in-sample data (X_train and y_train)

# %%
# Construct a dataframe using just the "y" training data:
in_sample_results = y_train.to_frame()

# Add a column of "in-sample" predictions to that DataFrame:  
in_sample_results["In-sample Predictions"] = model.predict(X_train)

# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
in_sample_mse = mean_squared_error(in_sample_results["Corn_Price_3Mo_Forward"],in_sample_results["In-sample Predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
in_sample_rmse = np.sqrt(in_sample_mse)

# Print the mser, rmse, and standard deviation
print(f"Mean Squared Error (MSE): {mse}")
print(f"In-sample Root Mean Squared Error (RMSE): {rmse}")
print(f"Standard Deviation of Futures Return: {np.std(in_sample_results.Corn_Price_3Mo_Forward)}")
# Out:
# Mean Squared Error (MSE): 0.12822577101185792
# In-sample Root Mean Squared Error (RMSE): 0.35808626197029386
# Standard Deviation of Futures Return: 1.493433726984591
